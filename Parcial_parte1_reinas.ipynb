# %%
import random

class Chessboard:
    def init_(self, *args):
        if len(args) <1:
            self.team_white = []
            self.team_black = []
            self.board = []
            self.letters = ["A", "B", "C", "D", "E", "F", "G", "H"] 
            self.numbers = ["8", "7", "6", "5", "4", "3", "2", "1"]


            for height in range(len(self.numbers)):
                current_row = []
                for position in range(len(self.letters)):
                    current_row.append(self.letters [position] + self.numbers [height])
                self.board.append(current_row)
                

    elif len(args) == 1 and type(args[0]) == Chessboard:
        self.team_white = args[0].team_white
        self.team_black = args [0].team_black
        self.board = args [0].board

        self.letters = ["A", "B", "C", "D", "E", "F", "G", "H"] 
        self.numbers = ["8", "7", "6", "5", "4", "3", "2", "1"]




else:
    print("copy constructor only takes one parameter")

def place_piece(self, piece, pos: str, team: str):
    position = self.translate_pos(pos)

    if self.board[position[0]][position[1]] != "Rb" or self.board[position[0]][position[1]] != "Rn":
        self.board[position[0]][position[1]]= "R" + piece.team[0] 
    else:
        print ("position occupied")
        
def print_board(self):
    for height in range(len(self.numbers)):
        aux=[]
        for position in range(len(self.letters)):
            aux.append(self.board[height ][position])
        print("\t", aux)

def translate_pos(self, pos: str):
    for height in range(len(self.numbers)):
        for position in range(len(self.letters)):
            if self.letters[position] == pos[0] and self.numbers[height] == pos[1]:
                return height, position
            else:
                print("position not Found")




    def invert(self):
        inverted_board = []
        

        for height in reversed(range(len(self.numbers))):
        current_row = []
        for position in reversed(range(len(self.letters))):
            current_row.append(self.board[height][position])
        inverted_board. append(current_row)
        

        for height in range(len(self.numbers)):
            for position in range(len(self.letters)):
                if inverted_board[height][position] != "Rb" and inverted_board[height][position] !=  "Rn":
                    inverted_board[height][position] = \
                        self.letters[position] + self.numbers[height]
                    
self.board = inverted_board

def play(self):
    solution = False
    cR1b = 0
    cR2b = 0
    cR1n = 0
    cR2n = 0


Q1w= Queen("white", [0, 0], self)
Q2n= Queen("white", [0, 7], self)
Q1b= Queen("black", [7, 0], self)
Q2b= Queen("black", [7, 7], self)


print("**Input Report**")
print ("starting positions:")
self.print_board()


objective = Chessboard(self)
objective.invert()

    while not solution:

        if self.board[R1b. placement [0]][R1b. placement [1]] != objective.board[R1b.placement [0]][R1b.placement [1]]:
            R1b.random_move(self)
            cR1b += 1
        
        if self.board[R2b. placement [0]][R2b. placement [1]] != objective.board[R2b. placement [0]][R2b. placement [1]]:
            R2b.random_move(self)
            cR2b +=1
      

        if self.board[R1n.placement [0]][R1n.placement[1]] != objective.board[R1n. placement[0]][R1n.placement [1]]:
            R1n.random_move(self)
            cR1n += 1
      
        if self.board[R2n. placement [0]][R2n.placement [1]] != objective.board[R2n.placement [0]][R2n. placement [1]]:
            R2n.random_move(self)
            cR2n += 1

        if self.board == objective.board:
            solution = true 

            
        print("\n\n***Output Report***")
        print("Number of moves :", cR1b + cR2b + cR1n + cR2n)
        print ("Final board: ")
        self.print_board()
        print("\nNumber of Rlb moves:", cRlb)
        print("Rlb move history: ", Rlb.visited_pos)
        print("\nNumber of R2b moves:", cR2b)
        print("R2b move history: ", R2b.visited_pos)
        print("\nNumber of Rln moves:", cRln)
        print("Rln move history: ", Rln.visited_pos)
        print("\nNumber of R2n moves:", cR2n)
        print("R2n move history: ", R2n.visited_pos)
    
    
    
class Queen:
    def _init_(self, team: str, pos: list[int], cb: Chessboard):
    self.team = team
    self.letters = ["A", "B", "C", "D", "E", "F", "G", "H"] 
    self.numbers = ["8", "7", "6", "5", "4", "3", "2", "1"]
    self.placement =[pos[0],  pos[1]]
    cb.board[pos [0]][pos[1]] = "R" + self.team[0]
    self.visited_pos = []


    def random_move(self, cb: Chessboard):
        possible_moves = self.check(cb)
  
        move  = possible_moves[random.randint(0, len(possible_moves) - 1)]
  
        self.visited_pos.append(self.letters[self.placement [1]] + self.numbers[self.placement[0]])

        cb.board[self.placement [0]][self.placement [1]] = \
          self.letters[self.placement [1]] + self.numbers[self.placement [0]]
  
        cb.board[move[0]][move[1]] ="R" + self.team[0]

        self.placement = [move[0], move[1]]

    def check(self, cb: Chessboard):
        possible_moves= []
        height = self.placement [0]
        position = self.placement [1]
        size = len(cb.letters)


#IMAGEN 7

    for element in range(len(cb. letters)):
        if not (cb.board[height ][element] == "Rb" or cb.board[height][element] =="Rn") \
                and cb.board[height][element] not in self.visited_pos:
            possible_moves.append([height, element])
              
    for element in range(len(cb.numbers)):
        if not (cb.board[element][position] == "Rb" or cb.board[element][position] == "Rn") \
                and cb.board[element ][position] not in self.visited_pos:
              possible_moves. append([element, position])


    aux_Height = height
    aux_Pos = position

    while aux_Height < size -1 and aux_Pos > 0:
            aux_Height += 1
            aux_Pos -= 1

    while aux_Height >= 0 and aux_Pos <= size - 1:
        if not (cb.board[aux_Height ][aux_Pos] == "Rb" or cb.board[aux_Height][aux_Pos] == "Rn") \
                and cb.board[aux_Height ][aux_Pos] not in self.visited_pos:
            possible_moves.append([aux_Height, aux_Pos])
        aux_Height -= 1
        aux_Pos += 1


    aux_Height = height
    aux_Pos = position
    
    while aux_Height >0 and aux_Pos> 0:
        aux_Height -= 1
        aux_Pos -= 1
         
    while aux_Height <= size -1 and aux_Pos <= size -1:
        if not (cb.board[aux_Height ][aux_Pos] == "Rb" or cb.board[aux_Height ][aux_Pos] == "Rn")\
                and cb.board[aux_Height ][aux_Pos] not in self.visited_pos:
            possible_moves.append([aux_Height, aux_pos])
        aux_Height += 1
        aux_Pos -= 1

    if len(possible_moves) == 0:
        self.visited_pos = []
        possible_moves = self.check(cb)

    return possible_moves
